# %%
import matplotlib.pyplot as plt
import numpy as np

from utils import *

# %%
WGAN = load_dict('loss')
BN = load_dict('loss_BN')
MLP4 = load_dict('loss_MLP')
MLP5 = load_dict('loss_MLP2')

# %%
plt.plot(WGAN['W'], label = 'DCGAN')
plt.legend(loc=1, ncol=1, fontsize = 'large')
plt.xlabel('Generator iterations')
plt.ylabel('Wasserstein estimate')
# Out:
# Text(0, 0.5, 'Wasserstein estimate')

# %%
plt.plot(BN['W'], label = 'DCGAN-BN')
plt.legend(loc=1, ncol=1, fontsize = 'large')
plt.xlabel('Generator iterations')
plt.ylabel('Wasserstein estimate')
# Out:
# Text(0, 0.5, 'Wasserstein estimate')

# %%
plt.plot(MLP4['W'], label = 'MLP-4')
plt.legend(loc=1, ncol=1, fontsize = 'large')
plt.xlabel('Generator iterations')
plt.ylabel('Wasserstein estimate')
# Out:
# Text(0, 0.5, 'Wasserstein estimate')

# %%
plt.plot(MLP5['W'], label = 'MLP-5')
plt.legend(loc=1, ncol=1, fontsize = 'large')
plt.xlabel('Generator iterations')
plt.ylabel('Wasserstein estimate')
# Out:
# Text(0, 0.5, 'Wasserstein estimate')

# %%
* MLP5 그래프 그려서 저장,
* generator sample 0, 10000, 50000, 100000, 200000, 300000, 400000, 500000, 600000
